# %%
# !pip install easyfsl
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import Omniglot
from torchvision.models import resnet18
from tqdm import tqdm

from easyfsl.samplers import TaskSampler
from easyfsl.utils import plot_images, sliding_average
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: easyfsl in /data/asufian/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /data/asufian/.local/lib/python3.10/site-packages (from easyfsl) (3.9.2)
# Requirement already satisfied: torchvision>=0.7.0 in /data/asufian/.local/lib/python3.10/site-packages (from easyfsl) (0.19.0)
# Requirement already satisfied: tqdm>=4.1.0 in /data/asufian/.local/lib/python3.10/site-packages (from easyfsl) (4.66.5)
# Requirement already satisfied: torch>=1.5.0 in /data/asufian/.local/lib/python3.10/site-packages (from easyfsl) (2.4.0)
# Requirement already satisfied: pandas>=1.5.0 in /data/asufian/.local/lib/python3.10/site-packages (from easyfsl) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->easyfsl) (21.3)
# Requirement already satisfied: numpy>=1.23 in /data/asufian/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (1.26.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->easyfsl) (4.29.1)
# Requirement already satisfied: python-dateutil>=2.7 in /data/asufian/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->easyfsl) (0.11.0)
# Requirement already satisfied: pillow>=8 in /data/asufian/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /data/asufian/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->easyfsl) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->easyfsl) (2.4.7)
# Requirement already satisfied: tzdata>=2022.7 in /data/asufian/.local/lib/python3.10/site-packages (from pandas>=1.5.0->easyfsl) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.5.0->easyfsl) (2022.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (10.3.2.106)
# Requirement already satisfied: fsspec in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (2024.6.1)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.5.0->easyfsl) (1.9)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (9.1.0.70)
# Requirement already satisfied: triton==3.0.0 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (4.12.2)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch>=1.5.0->easyfsl) (3.6.0)
# Requirement already satisfied: networkx in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (3.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (2.20.5)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (12.1.0.106)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (11.4.5.107)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (11.0.2.54)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.5.0->easyfsl) (3.0.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /data/asufian/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /data/asufian/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->easyfsl) (12.6.20)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->easyfsl) (1.16.0)
# /data/asufian/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import os
import random
from collections import defaultdict
from PIL import Image, ImageOps
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class PrototypicalOmniglotDataset(Dataset):
    def __init__(self, root, num_classes=1623, n_shot=5, n_query=10, transform=None):
        self.root = root
        self.num_classes = num_classes
        self.n_shot = n_shot
        self.n_query = n_query
        self.transform = transform
        self.samples_by_label = defaultdict(list)
        self.all_imgs = {}
        self.classes = []

        # Common image file extensions
        image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff', '.webp']

        # Organize data into classes and image paths
        for alphabet in os.listdir(self.root):
            alphabet_path = os.path.join(self.root, alphabet)
            if not os.path.isdir(alphabet_path):
                continue

            for char_class in os.listdir(alphabet_path):
                char_class_path = os.path.join(alphabet_path, char_class)

                # Skip if the entry is not a directory
                if not os.path.isdir(char_class_path):
                    continue

                all_images = []
                for img_name in os.listdir(char_class_path):
                    img_path = os.path.join(char_class_path, img_name)

                    # Check if it's a file with a recognized image extension
                    if os.path.isfile(img_path) and any(img_name.lower().endswith(ext) for ext in image_extensions):
                        all_images.append(img_path)

                if all_images:
                    char_class_name = f"{alphabet}_{char_class}"
                    self.samples_by_label[char_class_name] = list(range(len(all_images)))
                    self.all_imgs[char_class_name] = all_images
                    self.classes.append(char_class_name)

    def transform_image(self, raw_img):
#         img = ImageOps.invert(raw_img)
#         if self.transform is not None:
        img = self.transform(raw_img)
        return img

    def __getitem__(self, index):
        selected_classes = random.sample(self.classes, self.num_classes)
        class_indices = [self.samples_by_label[each_cls] for each_cls in selected_classes]

        support_set = []
        query_set = []
        label_id = 0
        qs=[]
        for idx_set in class_indices:
            # Creating support set
            selected_support = random.sample(idx_set, self.n_shot)
            support_images = [self.transform_image(Image.open(self.all_imgs[selected_classes[label_id]][each]).convert('RGB')) for each in selected_support]

            # Creating query set
            selected_query = random.sample(idx_set, self.n_query)
            query_images = [self.transform_image(Image.open(self.all_imgs[selected_classes[label_id]][each]).convert('RGB')) for each in selected_query]
            support_set.append((support_images, [label_id for _ in range(self.n_shot)]))
            # print("aaaaaaaaaa",label_id)
            query_set.append((query_images,  [label_id for _ in range(self.n_query)]))

            label_id += 1
            # qs= [item for item in a for _ in range(self.n_query)]
        return support_set, query_set

    def __len__(self):
        return 10

# Set up the transformations
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.ToTensor(),
])

# Set up the SiameseOmniglotDataset
# Training == evaluation
root_path = './final_training_processed_data'
num_classes = 5  # Set the desired number of classes per episode
n_shot = 5
n_query = 10

PrototypicalOmniglotDatasetLoader = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)

# %%
transform = transforms.Compose([
    transforms.Resize((200, 200)),  # Resize to expected size
    transforms.RandomRotation(degrees=30),  # Random rotation to address orientation issues
    transforms.RandomHorizontalFlip(p=0.5),  # Random horizontal flip
    transforms.RandomVerticalFlip(p=0.5),    # Random vertical flip
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),  # Stronger color jitter to account for color variation
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),  # Random translation for slight shift
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # ImageNet normalization (adjust if needed)
])


# Set up the PrototypicalOmniglotDatasetLoader
root_path ='./final_training_processed_data'# '/path/to/omniglot_dataset'
num_classes = 3
n_shot = 2
n_query = 3

dataset = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)
dataloader = DataLoader(dataset, batch_size=1, shuffle=False)
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a PrototypicalNetwork model
# model = PrototypicalNetwork(num_classes=num_classes).to(device)

# Set the model to evaluation mode
# model.eval()

# Choose an episode to visualize
episode_index = 10  # Change this to the desired episode index

# Get support set and query set for the chosen episode
support_set, query_set = dataset[episode_index]

# Visualize support set
for i, (support_images, lbl) in enumerate(support_set):
    for j, img in enumerate(support_images):
        plt.subplot(len(support_set), len(support_images), i * len(support_images) + j + 1)
        plt.imshow(img[0], cmap='gray')  # Assuming the image is grayscale
        plt.axis('off')
        plt.title(f'Support {i + 1}-{j + 1}{lbl[j]}')

plt.suptitle('Support Set')
plt.show()

# Visualize query set
for i, (query_images, ll) in enumerate(query_set):
    for j, img in enumerate(query_images):
        plt.subplot(len(query_set), len(query_images), i * len(query_images) + j + 1)
        plt.imshow(img[0], cmap='gray')  # Assuming the image is grayscale
        plt.axis('off')
        plt.title(f'Query {i + 1}-{ll[j]}')

plt.suptitle('Query Set')
plt.show()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import ViTImageProcessor, ViTModel
import torchvision.models as models

class ResNet18WithDropout(nn.Module):
    def __init__(self, pretrained=False, dr=0.5):
        super(ResNet18WithDropout, self).__init__()
        self.resnet18 = models.resnet18(pretrained=pretrained)
        self.dropout = nn.Dropout(dr)
        num_features = self.resnet18.fc.in_features
        self.resnet18.fc = nn.Linear(num_features, 1000)  # Example output size

    def forward(self, x):
        x = self.resnet18(x)
        x = self.dropout(x)
        return x

class PrototypicalNetworks3(nn.Module):
    def __init__(self, backbone: nn.Module, combined_dim: int, dropout_rate: float = 0.5):
        super(PrototypicalNetworks3, self).__init__()
        self.backbone = backbone
        self.vit_processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')
        self.vit_model = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
        
        # Freeze the weights of the ViT model
        self.freeze_vit()

        # FC layers with dropout
        self.fc = nn.Sequential(
            nn.Linear(combined_dim, 600),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(600, 500),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(500, 400)
        )

    def freeze_vit(self):
        for param in self.vit_model.parameters():
            param.requires_grad = False

    def rescale_to_vit_range(self, images: torch.Tensor) -> torch.Tensor:
        """
        Rescale image tensor to [0, 1] for ViT input.
        """
        images_rescaled = (images - images.min()) / (images.max() - images.min())
        return images_rescaled

    def forward(self, support_images, support_labels, query_images: torch.Tensor) -> torch.Tensor:
        """
        Predict query labels using labeled support images.
        """
        num_classes = len(support_labels)
        combined_prototypes = []

        for class_label in range(num_classes):
            support_images_eachclass = support_images[class_label]

            # Backbone features
            class_features_backbone = self.backbone(support_images_eachclass.to(device)).mean(dim=0)

            # ViT features
            support_images_vit = self.rescale_to_vit_range(support_images_eachclass)
            support_images_vit = self.vit_processor(images=support_images_vit, return_tensors="pt")['pixel_values']
            class_features_vit = self.vit_model(support_images_vit.to(device)).last_hidden_state.mean(dim=1).mean(dim=0)

            # Combine features
            combined_features = torch.cat((class_features_backbone, class_features_vit), dim=-1)
            combined_prototype = self.fc(combined_features)
            combined_prototypes.append(combined_prototype)
        
        combined_prototypes = torch.stack(combined_prototypes)

        # Backbone query features
        query_features_backbone = self.backbone(query_images)

        # ViT query features
        query_images_vit = self.rescale_to_vit_range(query_images)
        query_images_vit = self.vit_processor(images=query_images_vit, return_tensors="pt")['pixel_values']
        query_features_vit = self.vit_model(query_images_vit.to(device)).last_hidden_state.mean(dim=1).mean(dim=0)

        # Expand ViT features to match backbone features in terms of batch size
        query_features_vit = query_features_vit.unsqueeze(0).expand(query_features_backbone.shape[0], -1)

        # Combine query features
        combined_query_features = torch.cat((query_features_backbone, query_features_vit), dim=-1)
        combined_query_features = self.fc(combined_query_features)

        # Compute the distance between combined query features and combined prototypes
        distances = torch.cdist(combined_query_features, combined_prototypes)

        return -distances

# Instantiate the modified ResNet18 model with dropout
backbone = ResNet18WithDropout(pretrained=True, dr=0.3).to(device)

# Set combined_dim as the sum of the output dimensions from ResNet18 and ViT
combined_dim = 1000 + 768  # Ensure these dimensions match your model output sizes

# Instantiate the PrototypicalNetworks3 model

model = PrototypicalNetworks3(backbone=backbone, combined_dim=combined_dim,dropout_rate=0.3).to(device)

# Example input data
support_images = torch.randn(3, 4, 3, 200, 200).to(device)  # 3 classes, 4 support samples per class, 3 channels, 200x200 images
support_labels = torch.tensor([0, 1, 2]).to(device)
query_images = torch.randn(4, 3, 200, 200).to(device)  # 4 query samples, 3 channels, 200x200 images

# Forward pass
distances = model(support_images, support_labels, query_images)

# Print total and learnable parameter counts
def print_parameter_counts(model):
    total_params = sum(p.numel() for p in model.parameters())
    learnable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Total parameters: {total_params}")
    print(f"Learnable parameters: {learnable_params}")

print_parameter_counts(model)

# Configure optimizer with weight decay for L2 regularization
optimizer = optim.Adam(
    [
        {'params': model.backbone.parameters(), 'weight_decay': 1e-4},  # Apply weight decay to backbone
        {'params': model.fc.parameters(), 'weight_decay': 1e-4}  # Apply weight decay to FC layers
    ],
    lr=1e-3,
    weight_decay=1e-4 # Adjust weight decay here if needed
)
print(distances.shape)
# Out:
# /data/asufian/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /data/asufian/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# It looks like you are trying to rescale already rescaled images. If the input images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again.
# Total parameters: 99641060
# Learnable parameters: 13251812
# torch.Size([4, 3])

# %%
        
        
transform = transforms.Compose([
    transforms.Resize((200, 200)),  # Resize to the size expected by the model (e.g., 224x224)
    transforms.RandomHorizontalFlip(),  # Random horizontal flip for augmentation
    transforms.RandomVerticalFlip(),    # Random vertical flip for augmentation
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Random color jitter for augmentation
    transforms.ToTensor(),  # Convert image to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize with ImageNet statistics (adjust if needed)
])
        
        
# 
#background == Training

root_path = './final_training_processed_data'
num_classes = 5
n_shot = 10
n_query = 10
# generate_random_params_trainloader()
print(f"Generated random values - num_classes: {num_classes}, n_shot: {n_shot}, n_query: {n_query}")

optimizer = optim.Adam(
    [
        {'params': model.backbone.parameters(), 'weight_decay': 1e-2},  # Apply weight decay to backbone
        {'params': model.fc.parameters(), 'weight_decay': 1e-2}  # Apply weight decay to FC layers
    ],
    lr=0.0001,
    weight_decay=1e-2 # Adjust weight decay here if needed
)
print(distances.shape)


criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=0.004)
episode_losses = []

for episode in range(500):

    support_set, query_set = dataset[episode]

    # Convert data to tensors and move to device
    support_set = [(torch.stack(images).to(device), label[0]) for images, label in support_set]
    query_set = [(torch.stack(images).to(device), label) for images, label in query_set]

    # Forward pass
    support_images, support_labels = zip(*support_set)
    query_images, query_labels = zip(*query_set)
    # print(len(support_images),len(support_labels),type(support_images[0]),support_labels,)

    # support_images = torch.cat(support_images)
    # support_labels = torch.tensor(support_labels).to(device)
    query_images = torch.cat(query_images)
    query_labels = torch.tensor(query_labels).to(device)
    query_labels = query_labels.view(-1)
    tskloss = 0
    ta=""
    # print(query_labels)
    for i in range(40):
      model.train()

      classification_scores = model(support_images, support_labels, query_images)
      # print(classification_scores.shape)


      loss = criterion(classification_scores, query_labels)
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      tskloss+=loss.item()
      if(i==0 or i==19 or i==39):
        predicted_labels = torch.argmax(classification_scores, dim=1)
        pp=predicted_labels.tolist()
        act=query_labels.tolist()
        cortt=0
        for iii in range(len(pp)):
          if pp[iii] == act[iii]:
              cortt = cortt + 1
        print("Traning accuracy: ",cortt/len(pp))
        ta="Training Accuracy: ,"+str(cortt/len(pp))
      print("    --->>>   episode",episode,"mini_epoch:",i,"  train loss: ",loss.item())

# Calculate the total number of matching values
# total_matching_values = sum(matching_counts)

    episode_losses.append(tskloss)
    num_classes = random.choice([5,8])  # Random number of classes (e.g., between 3 and 10)
    n_shot = random.randint(1, 5)       # Random number of support examples per class (e.g., between 5 and 15)
    n_query = 15-n_shot
    dataset = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)
    print(f"Generated  Tasks - num_classes: {num_classes}, n_shot: {n_shot}, n_query: {n_query}")

    if episode%5==0:
      torch.save(model.state_dict(), './cGVit_res18__1'+'/G_vit_r189____'+str(episode)+'.pth')
# Out:
# Generated random values - num_classes: 5, n_shot: 10, n_query: 10
# torch.Size([4, 3])
# Traning accuracy:  0.1
#     --->>>   episode 0 mini_epoch: 0   train loss:  2.180184841156006
#     --->>>   episode 0 mini_epoch: 1   train loss:  1.8622276782989502
#     --->>>   episode 0 mini_epoch: 2   train loss:  1.6817309856414795
#     --->>>   episode 0 mini_epoch: 3   train loss:  1.5386207103729248
#     --->>>   episode 0 mini_epoch: 4   train loss:  1.4209096431732178
#     --->>>   episode 0 mini_epoch: 5   train loss:  1.3588522672653198
#     --->>>   episode 0 mini_epoch: 6   train loss:  1.336037278175354
#     --->>>   episode 0 mini_epoch: 7   train loss:  1.4053798913955688
#     --->>>   episode 0 mini_epoch: 8   train loss:  1.271716594696045
#     --->>>   episode 0 mini_epoch: 9   train loss:  1.2621400356292725
#     --->>>   episode 0 mini_epoch: 10   train loss:  1.2799463272094727
#     --->>>   episode 0 mini_epoch: 11   train loss:  1.2650247812271118
#     --->>>   episode 0 mini_epoch: 12   train loss:  1.29320228099823
#     --->>>   episode 0 mini_epoch: 13   train loss:  1.181383490562439
#     --->>>   episode 0 mini_epoch: 14   train loss:  1.14383065700531
#     --->>>   episode 0 mini_epoch: 15   train loss:  1.1709868907928467
#     --->>>   episode 0 mini_epoch: 16   train loss:  1.1827129125595093
#     --->>>   episode 0 mini_epoch: 17   train loss:  1.160622477531433
#     --->>>   episode 0 mini_epoch: 18   train loss:  1.2186578512191772
# Traning accuracy:  0.475
#     --->>>   episode 0 mini_epoch: 19   train loss:  1.0423672199249268
#     --->>>   episode 0 mini_epoch: 20   train loss:  1.3393408060073853
#     --->>>   episode 0 mini_epoch: 21   train loss:  1.0532324314117432
#     --->>>   episode 0 mini_epoch: 22   train loss:  1.0129750967025757
#     --->>>   episode 0 mini_epoch: 23   train loss:  1.044308066368103
#     --->>>   episode 0 mini_epoch: 24   train loss:  1.0239331722259521
#     --->>>   episode 0 mini_epoch: 25   train loss:  1.2671968936920166
#     --->>>   episode 0 mini_epoch: 26   train loss:  1.0707589387893677
#     --->>>   episode 0 mini_epoch: 27   train loss:  1.1638376712799072
#     --->>>   episode 0 mini_epoch: 28   train loss:  1.0521976947784424
#     --->>>   episode 0 mini_epoch: 29   train loss:  0.986209511756897
#     --->>>   episode 0 mini_epoch: 30   train loss:  1.008815050125122
#     --->>>   episode 0 mini_epoch: 31   train loss:  1.037778377532959
#     --->>>   episode 0 mini_epoch: 32   train loss:  0.8808175325393677
#     --->>>   episode 0 mini_epoch: 33   train loss:  0.9156292676925659
#     --->>>   episode 0 mini_epoch: 34   train loss:  0.9567429423332214
#     --->>>   episode 0 mini_epoch: 35   train loss:  0.9427397847175598
#     --->>>   episode 0 mini_epoch: 36   train loss:  0.9118088483810425
#     --->>>   episode 0 mini_epoch: 37   train loss:  0.9628719091415405
#     --->>>   episode 0 mini_epoch: 38   train loss:  0.8391271829605103
# Traning accuracy:  0.575
#     --->>>   episode 0 mini_epoch: 39   train loss:  0.9703667759895325
# Generated  Tasks - num_classes: 8, n_shot: 5, n_query: 10
# Traning accuracy:  0.1625
#     --->>>   episode 1 mini_epoch: 0   train loss:  2.130326747894287
#     --->>>   episode 1 mini_epoch: 1   train loss:  2.1648001670837402
#     --->>>   episode 1 mini_epoch: 2   train loss:  2.1422057151794434
#     --->>>   episode 1 mini_epoch: 3   train loss:  2.096644163131714
#     --->>>   episode 1 mini_epoch: 4   train loss:  1.9795697927474976
#     --->>>   episode 1 mini_epoch: 5   train loss:  1.8136951923370361
#     --->>>   episode 1 mini_epoch: 6   train loss:  1.6464197635650635
#     --->>>   episode 1 mini_epoch: 7   train loss:  1.638858437538147
#     --->>>   episode 1 mini_epoch: 8   train loss:  1.723576307296753
#     --->>>   episode 1 mini_epoch: 9   train loss:  1.520818829536438
#     --->>>   episode 1 mini_epoch: 10   train loss:  1.433615803718567
#     --->>>   episode 1 mini_epoch: 11   train loss:  1.306171178817749
#     --->>>   episode 1 mini_epoch: 12   train loss:  1.2378520965576172
#     --->>>   episode 1 mini_epoch: 13   train loss:  1.1337060928344727
#     --->>>   episode 1 mini_epoch: 14   train loss:  1.3497897386550903
#     --->>>   episode 1 mini_epoch: 15   train loss:  1.2491180896759033
#     --->>>   episode 1 mini_epoch: 16   train loss:  1.0643019676208496
#     --->>>   episode 1 mini_epoch: 17   train loss:  1.0317493677139282
#     --->>>   episode 1 mini_epoch: 18   train loss:  1.1792094707489014
# Traning accuracy:  0.6375
#     --->>>   episode 1 mini_epoch: 19   train loss:  0.9773238301277161
#     --->>>   episode 1 mini_epoch: 20   train loss:  0.958419144153595
#     --->>>   episode 1 mini_epoch: 21   train loss:  0.9249593019485474
#     --->>>   episode 1 mini_epoch: 22   train loss:  0.8975090980529785
#     --->>>   episode 1 mini_epoch: 23   train loss:  0.8752366304397583
#     --->>>   episode 1 mini_epoch: 24   train loss:  0.8634318113327026
#     --->>>   episode 1 mini_epoch: 25   train loss:  0.8113406896591187
#     --->>>   episode 1 mini_epoch: 26   train loss:  0.8102782368659973
#     --->>>   episode 1 mini_epoch: 27   train loss:  0.832414984703064
#     --->>>   episode 1 mini_epoch: 28   train loss:  0.7781948447227478
#     --->>>   episode 1 mini_epoch: 29   train loss:  0.7713819742202759
#     --->>>   episode 1 mini_epoch: 30   train loss:  0.8073394894599915
#     --->>>   episode 1 mini_epoch: 31   train loss:  0.7449179291725159
#     --->>>   episode 1 mini_epoch: 32   train loss:  0.7563363313674927
#     --->>>   episode 1 mini_epoch: 33   train loss:  0.6172274351119995
#     --->>>   episode 1 mini_epoch: 34   train loss:  0.7298752665519714
#     --->>>   episode 1 mini_epoch: 35   train loss:  0.7106783986091614
#     --->>>   episode 1 mini_epoch: 36   train loss:  0.6449612379074097
#     --->>>   episode 1 mini_epoch: 37   train loss:  0.6684631109237671
#     --->>>   episode 1 mini_epoch: 38   train loss:  0.5709319710731506
# Traning accuracy:  0.7375
#     --->>>   episode 1 mini_epoch: 39   train loss:  0.751265823841095
# Generated  Tasks - num_classes: 5, n_shot: 4, n_query: 11
# Traning accuracy:  0.14545454545454545
#     --->>>   episode 2 mini_epoch: 0   train loss:  2.0793862342834473
#     --->>>   episode 2 mini_epoch: 1   train loss:  1.583186149597168
#     --->>>   episode 2 mini_epoch: 2   train loss:  1.544323444366455
#     --->>>   episode 2 mini_epoch: 3   train loss:  1.5230154991149902
#     --->>>   episode 2 mini_epoch: 4   train loss:  1.2978988885879517
#     --->>>   episode 2 mini_epoch: 5   train loss:  1.1794322729110718
#     --->>>   episode 2 mini_epoch: 6   train loss:  1.1179064512252808
#     --->>>   episode 2 mini_epoch: 7   train loss:  1.0392674207687378
#     --->>>   episode 2 mini_epoch: 8   train loss:  1.0944511890411377
#     --->>>   episode 2 mini_epoch: 9   train loss:  1.3526400327682495
#     --->>>   episode 2 mini_epoch: 10   train loss:  1.0759660005569458
#     --->>>   episode 2 mini_epoch: 11   train loss:  0.8656497597694397
#     --->>>   episode 2 mini_epoch: 12   train loss:  0.7376818656921387
#     --->>>   episode 2 mini_epoch: 13   train loss:  0.9849534630775452
#     --->>>   episode 2 mini_epoch: 14   train loss:  0.8319441080093384
#     --->>>   episode 2 mini_epoch: 15   train loss:  0.5686469078063965
#     --->>>   episode 2 mini_epoch: 16   train loss:  0.6032906770706177
#     --->>>   episode 2 mini_epoch: 17   train loss:  0.5448620319366455
#     --->>>   episode 2 mini_epoch: 18   train loss:  0.5582839846611023
# Traning accuracy:  0.7636363636363637
#     --->>>   episode 2 mini_epoch: 19   train loss:  0.5548246502876282
#     --->>>   episode 2 mini_epoch: 20   train loss:  0.5251195430755615
#     --->>>   episode 2 mini_epoch: 21   train loss:  0.5327240824699402
#     --->>>   episode 2 mini_epoch: 22   train loss:  0.484851598739624
#     --->>>   episode 2 mini_epoch: 23   train loss:  0.47886407375335693
#     --->>>   episode 2 mini_epoch: 24   train loss:  0.4481022357940674
#     --->>>   episode 2 mini_epoch: 25   train loss:  0.49569281935691833
#     --->>>   episode 2 mini_epoch: 26   train loss:  0.3977107107639313
#     --->>>   episode 2 mini_epoch: 27   train loss:  0.39344358444213867
#     --->>>   episode 2 mini_epoch: 28   train loss:  0.45966166257858276
#     --->>>   episode 2 mini_epoch: 29   train loss:  0.36127176880836487
#     --->>>   episode 2 mini_epoch: 30   train loss:  0.42144450545310974
#     --->>>   episode 2 mini_epoch: 31   train loss:  0.4022805988788605
#     --->>>   episode 2 mini_epoch: 32   train loss:  0.373588502407074
#     --->>>   episode 2 mini_epoch: 33   train loss:  0.35719144344329834
#     --->>>   episode 2 mini_epoch: 34   train loss:  0.35926347970962524
#     --->>>   episode 2 mini_epoch: 35   train loss:  0.3328379690647125
#     --->>>   episode 2 mini_epoch: 36   train loss:  0.3043932616710663
#     --->>>   episode 2 mini_epoch: 37   train loss:  0.31544020771980286
#     --->>>   episode 2 mini_epoch: 38   train loss:  0.35348501801490784
# Traning accuracy:  0.9272727272727272
#     --->>>   episode 2 mini_epoch: 39   train loss:  0.29855120182037354
# Generated  Tasks - num_classes: 8, n_shot: 1, n_query: 14
# Traning accuracy:  0.09821428571428571
#     --->>>   episode 3 mini_epoch: 0   train loss:  4.873281002044678
#     --->>>   episode 3 mini_epoch: 1   train loss:  3.0426065921783447
#     --->>>   episode 3 mini_epoch: 2   train loss:  2.5150086879730225
#     --->>>   episode 3 mini_epoch: 3   train loss:  2.4294207096099854
#     --->>>   episode 3 mini_epoch: 4   train loss:  2.1464920043945312
#     --->>>   episode 3 mini_epoch: 5   train loss:  2.0151031017303467
#     --->>>   episode 3 mini_epoch: 6   train loss:  2.090602159500122
#     --->>>   episode 3 mini_epoch: 7   train loss:  2.122934103012085
#     --->>>   episode 3 mini_epoch: 8   train loss:  1.9730138778686523
#     --->>>   episode 3 mini_epoch: 9   train loss:  1.9424312114715576
#     --->>>   episode 3 mini_epoch: 10   train loss:  1.9626657962799072
#     --->>>   episode 3 mini_epoch: 11   train loss:  1.9422191381454468
#     --->>>   episode 3 mini_epoch: 12   train loss:  1.9248772859573364
#     --->>>   episode 3 mini_epoch: 13   train loss:  1.8840619325637817
#     --->>>   episode 3 mini_epoch: 14   train loss:  1.9225914478302002
#     --->>>   episode 3 mini_epoch: 15   train loss:  1.864477276802063
#     --->>>   episode 3 mini_epoch: 16   train loss:  1.8587400913238525
#     --->>>   episode 3 mini_epoch: 17   train loss:  1.7813568115234375
#     --->>>   episode 3 mini_epoch: 18   train loss:  1.754607081413269
# Traning accuracy:  0.2857142857142857
#     --->>>   episode 3 mini_epoch: 19   train loss:  1.6915616989135742
#     --->>>   episode 3 mini_epoch: 20   train loss:  1.6195567846298218
#     --->>>   episode 3 mini_epoch: 21   train loss:  1.5947223901748657
#     --->>>   episode 3 mini_epoch: 22   train loss:  1.6206213235855103
#     --->>>   episode 3 mini_epoch: 23   train loss:  1.6458321809768677
#     --->>>   episode 3 mini_epoch: 24   train loss:  1.4364114999771118
#     --->>>   episode 3 mini_epoch: 25   train loss:  1.457167387008667
#     --->>>   episode 3 mini_epoch: 26   train loss:  1.3113058805465698
#     --->>>   episode 3 mini_epoch: 27   train loss:  1.2836307287216187
#     --->>>   episode 3 mini_epoch: 28   train loss:  1.2006829977035522
#     --->>>   episode 3 mini_epoch: 29   train loss:  1.137717604637146
#     --->>>   episode 3 mini_epoch: 30   train loss:  1.1102906465530396
#     --->>>   episode 3 mini_epoch: 31   train loss:  1.083831787109375
#     --->>>   episode 3 mini_epoch: 32   train loss:  0.9916239380836487
#     --->>>   episode 3 mini_epoch: 33   train loss:  0.8710857033729553
#     --->>>   episode 3 mini_epoch: 34   train loss:  0.9046258330345154
#     --->>>   episode 3 mini_epoch: 35   train loss:  0.905100405216217
#     --->>>   episode 3 mini_epoch: 36   train loss:  0.7987402677536011
#     --->>>   episode 3 mini_epoch: 37   train loss:  0.8060466051101685
#     --->>>   episode 3 mini_epoch: 38   train loss:  0.6866269111633301
# Traning accuracy:  0.6785714285714286
#     --->>>   episode 3 mini_epoch: 39   train loss:  0.8765993714332581
# Generated  Tasks - num_classes: 8, n_shot: 5, n_query: 10
# Traning accuracy:  0.125
#     --->>>   episode 4 mini_epoch: 0   train loss:  2.617119312286377
#     --->>>   episode 4 mini_epoch: 1   train loss:  2.438573122024536
#     --->>>   episode 4 mini_epoch: 2   train loss:  2.112501859664917
#     --->>>   episode 4 mini_epoch: 3   train loss:  2.111569881439209
#     --->>>   episode 4 mini_epoch: 4   train loss:  2.3140220642089844
#     --->>>   episode 4 mini_epoch: 5   train loss:  2.0070810317993164
#     --->>>   episode 4 mini_epoch: 6   train loss:  2.171576738357544
#     --->>>   episode 4 mini_epoch: 7   train loss:  1.8503837585449219
#     --->>>   episode 4 mini_epoch: 8   train loss:  1.7587897777557373
#     --->>>   episode 4 mini_epoch: 9   train loss:  1.8345909118652344
#     --->>>   episode 4 mini_epoch: 10   train loss:  1.877388596534729
#     --->>>   episode 4 mini_epoch: 11   train loss:  1.7640870809555054
#     --->>>   episode 4 mini_epoch: 12   train loss:  1.6905720233917236
#     --->>>   episode 4 mini_epoch: 13   train loss:  1.727481484413147
#     --->>>   episode 4 mini_epoch: 14   train loss:  1.6749646663665771
#     --->>>   episode 4 mini_epoch: 15   train loss:  1.635841727256775
#     --->>>   episode 4 mini_epoch: 16   train loss:  1.5727601051330566
#     --->>>   episode 4 mini_epoch: 17   train loss:  1.6581159830093384
#     --->>>   episode 4 mini_epoch: 18   train loss:  1.4999457597732544
# Traning accuracy:  0.425
#     --->>>   episode 4 mini_epoch: 19   train loss:  1.4341989755630493
#     --->>>   episode 4 mini_epoch: 20   train loss:  1.3880544900894165
#     --->>>   episode 4 mini_epoch: 21   train loss:  1.4623768329620361
#     --->>>   episode 4 mini_epoch: 22   train loss:  1.4027817249298096
#     --->>>   episode 4 mini_epoch: 23   train loss:  1.3552101850509644
#     --->>>   episode 4 mini_epoch: 24   train loss:  1.3002756834030151
#     --->>>   episode 4 mini_epoch: 25   train loss:  1.2096853256225586
#     --->>>   episode 4 mini_epoch: 26   train loss:  1.2741649150848389
#     --->>>   episode 4 mini_epoch: 27   train loss:  1.1793618202209473
#     --->>>   episode 4 mini_epoch: 28   train loss:  1.1275546550750732
#     --->>>   episode 4 mini_epoch: 29   train loss:  1.1165851354599
#     --->>>   episode 4 mini_epoch: 30   train loss:  1.0543348789215088
#     --->>>   episode 4 mini_epoch: 31   train loss:  0.980700671672821
#     --->>>   episode 4 mini_epoch: 32   train loss:  1.0926978588104248
#     --->>>   episode 4 mini_epoch: 33   train loss:  1.0650925636291504
#     --->>>   episode 4 mini_epoch: 34   train loss:  0.9842107892036438
#     --->>>   episode 4 mini_epoch: 35   train loss:  1.0925650596618652
#     --->>>   episode 4 mini_epoch: 36   train loss:  0.8289015889167786
#     --->>>   episode 4 mini_epoch: 37   train loss:  1.0733344554901123
#     --->>>   episode 4 mini_epoch: 38   train loss:  0.8486350178718567
# Traning accuracy:  0.7375
#     --->>>   episode 4 mini_epoch: 39   train loss:  0.791990339756012
# Generated  Tasks - num_classes: 8, n_shot: 3, n_query: 12
# Traning accuracy:  0.1875
#     --->>>   episode 5 mini_epoch: 0   train loss:  2.442037582397461
#     --->>>   episode 5 mini_epoch: 1   train loss:  2.0686333179473877
#     --->>>   episode 5 mini_epoch: 2   train loss:  2.1471636295318604
#     --->>>   episode 5 mini_epoch: 3   train loss:  1.9992319345474243
#     --->>>   episode 5 mini_epoch: 4   train loss:  2.1554720401763916
#     --->>>   episode 5 mini_epoch: 5   train loss:  1.923073172569275
#     --->>>   episode 5 mini_epoch: 6   train loss:  1.868306040763855
#     --->>>   episode 5 mini_epoch: 7   train loss:  1.822991967201233
#     --->>>   episode 5 mini_epoch: 8   train loss:  1.6524420976638794
#     --->>>   episode 5 mini_epoch: 9   train loss:  1.5620781183242798
#     --->>>   episode 5 mini_epoch: 10   train loss:  1.4816762208938599
#     --->>>   episode 5 mini_epoch: 11   train loss:  1.3990484476089478
#     --->>>   episode 5 mini_epoch: 12   train loss:  1.4079208374023438
#     --->>>   episode 5 mini_epoch: 13   train loss:  1.2717036008834839
#     --->>>   episode 5 mini_epoch: 14   train loss:  1.2169139385223389
#     --->>>   episode 5 mini_epoch: 15   train loss:  1.16580069065094
#     --->>>   episode 5 mini_epoch: 16   train loss:  1.007220983505249
#     --->>>   episode 5 mini_epoch: 17   train loss:  0.9764801859855652
#     --->>>   episode 5 mini_epoch: 18   train loss:  0.8677341938018799
# Traning accuracy:  0.6979166666666666
#     --->>>   episode 5 mini_epoch: 19   train loss:  0.7879533767700195
#     --->>>   episode 5 mini_epoch: 20   train loss:  0.7476314902305603
#     --->>>   episode 5 mini_epoch: 21   train loss:  0.7391100525856018
#     --->>>   episode 5 mini_epoch: 22   train loss:  0.715923547744751
#     --->>>   episode 5 mini_epoch: 23   train loss:  0.6906638741493225
#     --->>>   episode 5 mini_epoch: 24   train loss:  0.7409502863883972
#     --->>>   episode 5 mini_epoch: 25   train loss:  0.6409460306167603
#     --->>>   episode 5 mini_epoch: 26   train loss:  0.7244570255279541
#     --->>>   episode 5 mini_epoch: 27   train loss:  0.6112342476844788
#     --->>>   episode 5 mini_epoch: 28   train loss:  0.7635172009468079
#     --->>>   episode 5 mini_epoch: 29   train loss:  0.5276405811309814
#     --->>>   episode 5 mini_epoch: 30   train loss:  0.6736646294593811
#     --->>>   episode 5 mini_epoch: 31   train loss:  0.8172226548194885
#     --->>>   episode 5 mini_epoch: 32   train loss:  0.5320844054222107
#     --->>>   episode 5 mini_epoch: 33   train loss:  0.599736750125885
#     --->>>   episode 5 mini_epoch: 34   train loss:  0.6388168931007385
#     --->>>   episode 5 mini_epoch: 35   train loss:  0.6729589104652405
#     --->>>   episode 5 mini_epoch: 36   train loss:  0.5131064653396606
#     --->>>   episode 5 mini_epoch: 37   train loss:  0.6743715405464172
#     --->>>   episode 5 mini_epoch: 38   train loss:  0.6142033934593201
# Traning accuracy:  0.8229166666666666
#     --->>>   episode 5 mini_epoch: 39   train loss:  0.45927658677101135
# Generated  Tasks - num_classes: 5, n_shot: 4, n_query: 11
# Traning accuracy:  0.2545454545454545
#     --->>>   episode 6 mini_epoch: 0   train loss:  2.129761219024658
#     --->>>   episode 6 mini_epoch: 1   train loss:  1.3473163843154907
#     --->>>   episode 6 mini_epoch: 2   train loss:  1.6638033390045166
#     --->>>   episode 6 mini_epoch: 3   train loss:  1.3890324831008911
#     --->>>   episode 6 mini_epoch: 4   train loss:  1.05135977268219
#     --->>>   episode 6 mini_epoch: 5   train loss:  1.0868808031082153
#     --->>>   episode 6 mini_epoch: 6   train loss:  0.9447097182273865
#     --->>>   episode 6 mini_epoch: 7   train loss:  0.9603465795516968
#     --->>>   episode 6 mini_epoch: 8   train loss:  0.7674119472503662
#     --->>>   episode 6 mini_epoch: 9   train loss:  0.916269063949585
#     --->>>   episode 6 mini_epoch: 10   train loss:  0.7186901569366455
#     --->>>   episode 6 mini_epoch: 11   train loss:  0.6174716353416443
#     --->>>   episode 6 mini_epoch: 12   train loss:  0.5505126714706421
#     --->>>   episode 6 mini_epoch: 13   train loss:  0.5022017955780029
#     --->>>   episode 6 mini_epoch: 14   train loss:  0.4719850718975067
#     --->>>   episode 6 mini_epoch: 15   train loss:  0.37448665499687195
#     --->>>   episode 6 mini_epoch: 16   train loss:  0.42586320638656616
#     --->>>   episode 6 mini_epoch: 17   train loss:  0.2859959304332733
#     --->>>   episode 6 mini_epoch: 18   train loss:  0.31864285469055176
# Traning accuracy:  0.9818181818181818
#     --->>>   episode 6 mini_epoch: 19   train loss:  0.19361664354801178
#     --->>>   episode 6 mini_epoch: 20   train loss:  0.2992860674858093
#     --->>>   episode 6 mini_epoch: 21   train loss:  0.2212769240140915
#     --->>>   episode 6 mini_epoch: 22   train loss:  0.09624355286359787
#     --->>>   episode 6 mini_epoch: 23   train loss:  0.1560472697019577
#     --->>>   episode 6 mini_epoch: 24   train loss:  0.104573093354702
#     --->>>   episode 6 mini_epoch: 25   train loss:  0.13006579875946045
#     --->>>   episode 6 mini_epoch: 26   train loss:  0.21743477880954742
#     --->>>   episode 6 mini_epoch: 27   train loss:  0.03817762807011604
#     --->>>   episode 6 mini_epoch: 28   train loss:  0.16297894716262817
#     --->>>   episode 6 mini_epoch: 29   train loss:  0.04804345220327377
#     --->>>   episode 6 mini_epoch: 30   train loss:  0.05309697613120079
#     --->>>   episode 6 mini_epoch: 31   train loss:  0.08982711285352707
#     --->>>   episode 6 mini_epoch: 32   train loss:  0.03690442070364952
#     --->>>   episode 6 mini_epoch: 33   train loss:  0.08335250616073608
#     --->>>   episode 6 mini_epoch: 34   train loss:  0.04580263793468475
#     --->>>   episode 6 mini_epoch: 35   train loss:  0.058398567140102386
#     --->>>   episode 6 mini_epoch: 36   train loss:  0.03291179612278938
#     --->>>   episode 6 mini_epoch: 37   train loss:  0.017694175243377686
#     --->>>   episode 6 mini_epoch: 38   train loss:  0.02961229905486107
# Traning accuracy:  0.9818181818181818
#     --->>>   episode 6 mini_epoch: 39   train loss:  0.06265377253293991
# Generated  Tasks - num_classes: 8, n_shot: 2, n_query: 13
# Traning accuracy:  0.10576923076923077
#     --->>>   episode 7 mini_epoch: 0   train loss:  3.9105570316314697
#     --->>>   episode 7 mini_epoch: 1   train loss:  2.6496570110321045
#     --->>>   episode 7 mini_epoch: 2   train loss:  2.782526731491089
#     --->>>   episode 7 mini_epoch: 3   train loss:  2.7098186016082764
#     --->>>   episode 7 mini_epoch: 4   train loss:  2.53055477142334
#     --->>>   episode 7 mini_epoch: 5   train loss:  2.2490110397338867
#     --->>>   episode 7 mini_epoch: 6   train loss:  2.18155837059021
#     --->>>   episode 7 mini_epoch: 7   train loss:  2.088945150375366
#     --->>>   episode 7 mini_epoch: 8   train loss:  2.0065062046051025
#     --->>>   episode 7 mini_epoch: 9   train loss:  1.9692422151565552
#     --->>>   episode 7 mini_epoch: 10   train loss:  2.123049020767212
#     --->>>   episode 7 mini_epoch: 11   train loss:  2.0056281089782715
#     --->>>   episode 7 mini_epoch: 12   train loss:  2.0560388565063477
#     --->>>   episode 7 mini_epoch: 13   train loss:  2.037557601928711
#     --->>>   episode 7 mini_epoch: 14   train loss:  2.0281312465667725
#     --->>>   episode 7 mini_epoch: 15   train loss:  1.9020127058029175
#     --->>>   episode 7 mini_epoch: 16   train loss:  1.819448709487915
#     --->>>   episode 7 mini_epoch: 17   train loss:  1.7941304445266724
#     --->>>   episode 7 mini_epoch: 18   train loss:  1.8360952138900757
# Traning accuracy:  0.3173076923076923
#     --->>>   episode 7 mini_epoch: 19   train loss:  1.7044519186019897
#     --->>>   episode 7 mini_epoch: 20   train loss:  1.6800223588943481
#     --->>>   episode 7 mini_epoch: 21   train loss:  1.6493045091629028
#     --->>>   episode 7 mini_epoch: 22   train loss:  1.6098387241363525
#     --->>>   episode 7 mini_epoch: 23   train loss:  1.5903992652893066
#     --->>>   episode 7 mini_epoch: 24   train loss:  1.638322353363037
#     --->>>   episode 7 mini_epoch: 25   train loss:  1.4765032529830933
#     --->>>   episode 7 mini_epoch: 26   train loss:  1.3947678804397583
#     --->>>   episode 7 mini_epoch: 27   train loss:  1.4035311937332153
#     --->>>   episode 7 mini_epoch: 28   train loss:  1.2513236999511719
#     --->>>   episode 7 mini_epoch: 29   train loss:  1.18626868724823
#     --->>>   episode 7 mini_epoch: 30   train loss:  1.106305718421936
#     --->>>   episode 7 mini_epoch: 31   train loss:  1.0125257968902588
#     --->>>   episode 7 mini_epoch: 32   train loss:  0.9745714664459229
#     --->>>   episode 7 mini_epoch: 33   train loss:  0.8900501728057861
#     --->>>   episode 7 mini_epoch: 34   train loss:  0.8512921929359436
#     --->>>   episode 7 mini_epoch: 35   train loss:  0.8292768001556396
#     --->>>   episode 7 mini_epoch: 36   train loss:  0.7324256896972656
#     --->>>   episode 7 mini_epoch: 37   train loss:  0.7312768697738647
#     --->>>   episode 7 mini_epoch: 38   train loss:  0.5946681499481201
# Traning accuracy:  0.6153846153846154
#     --->>>   episode 7 mini_epoch: 39   train loss:  0.7048394680023193
# Generated  Tasks - num_classes: 8, n_shot: 4, n_query: 11
# Traning accuracy:  0.1590909090909091
#     --->>>   episode 8 mini_epoch: 0   train loss:  2.7822060585021973
#     --->>>   episode 8 mini_epoch: 1   train loss:  2.0807244777679443
#     --->>>   episode 8 mini_epoch: 2   train loss:  1.8975509405136108
#     --->>>   episode 8 mini_epoch: 3   train loss:  1.853247046470642
#     --->>>   episode 8 mini_epoch: 4   train loss:  1.980065941810608
#     --->>>   episode 8 mini_epoch: 5   train loss:  1.7273598909378052
#     --->>>   episode 8 mini_epoch: 6   train loss:  1.7327370643615723
#     --->>>   episode 8 mini_epoch: 7   train loss:  1.5950970649719238
#     --->>>   episode 8 mini_epoch: 8   train loss:  1.8308639526367188
#     --->>>   episode 8 mini_epoch: 9   train loss:  1.757757306098938
#     --->>>   episode 8 mini_epoch: 10   train loss:  1.4447715282440186
#     --->>>   episode 8 mini_epoch: 11   train loss:  1.4456099271774292
#     --->>>   episode 8 mini_epoch: 12   train loss:  1.3635109663009644
#     --->>>   episode 8 mini_epoch: 13   train loss:  1.3610376119613647
#     --->>>   episode 8 mini_epoch: 14   train loss:  1.2911171913146973
#     --->>>   episode 8 mini_epoch: 15   train loss:  1.2931281328201294
#     --->>>   episode 8 mini_epoch: 16   train loss:  1.325044870376587
#     --->>>   episode 8 mini_epoch: 17   train loss:  1.238075613975525
#     --->>>   episode 8 mini_epoch: 18   train loss:  1.0488547086715698
# Traning accuracy:  0.5340909090909091
#     --->>>   episode 8 mini_epoch: 19   train loss:  0.9290482997894287
#     --->>>   episode 8 mini_epoch: 20   train loss:  0.9806204438209534
#     --->>>   episode 8 mini_epoch: 21   train loss:  0.954048216342926
#     --->>>   episode 8 mini_epoch: 22   train loss:  0.9294605255126953
#     --->>>   episode 8 mini_epoch: 23   train loss:  0.9412715435028076
#     --->>>   episode 8 mini_epoch: 24   train loss:  0.8568946719169617
#     --->>>   episode 8 mini_epoch: 25   train loss:  0.8972869515419006
#     --->>>   episode 8 mini_epoch: 26   train loss:  0.8696274161338806
#     --->>>   episode 8 mini_epoch: 27   train loss:  0.7308804988861084
#     --->>>   episode 8 mini_epoch: 28   train loss:  0.7222558259963989
#     --->>>   episode 8 mini_epoch: 29   train loss:  0.7000023722648621
#     --->>>   episode 8 mini_epoch: 30   train loss:  0.6218904852867126
#     --->>>   episode 8 mini_epoch: 31   train loss:  0.6652078032493591
#     --->>>   episode 8 mini_epoch: 32   train loss:  0.6355686783790588
#     --->>>   episode 8 mini_epoch: 33   train loss:  0.6098060011863708
#     --->>>   episode 8 mini_epoch: 34   train loss:  0.5508968830108643
#     --->>>   episode 8 mini_epoch: 35   train loss:  0.524381697177887
#     --->>>   episode 8 mini_epoch: 36   train loss:  0.6018791794776917
#     --->>>   episode 8 mini_epoch: 37   train loss:  0.5072184205055237
#     --->>>   episode 8 mini_epoch: 38   train loss:  0.4105287790298462
# Traning accuracy:  0.8068181818181818
#     --->>>   episode 8 mini_epoch: 39   train loss:  0.4028744697570801
# Generated  Tasks - num_classes: 8, n_shot: 5, n_query: 10
# Traning accuracy:  0.15
#     --->>>   episode 9 mini_epoch: 0   train loss:  2.9808764457702637
#     --->>>   episode 9 mini_epoch: 1   train loss:  2.4716439247131348
#     --->>>   episode 9 mini_epoch: 2   train loss:  2.086132526397705
#     --->>>   episode 9 mini_epoch: 3   train loss:  2.111509084701538
#     --->>>   episode 9 mini_epoch: 4   train loss:  2.1834874153137207
#     --->>>   episode 9 mini_epoch: 5   train loss:  2.0766091346740723
#     --->>>   episode 9 mini_epoch: 6   train loss:  2.434884548187256
#     --->>>   episode 9 mini_epoch: 7   train loss:  1.9927173852920532
#     --->>>   episode 9 mini_epoch: 8   train loss:  2.1031322479248047
#     --->>>   episode 9 mini_epoch: 9   train loss:  1.925696611404419
#     --->>>   episode 9 mini_epoch: 10   train loss:  1.8916072845458984
#     --->>>   episode 9 mini_epoch: 11   train loss:  1.8835779428482056
#     --->>>   episode 9 mini_epoch: 12   train loss:  1.7567732334136963
#     --->>>   episode 9 mini_epoch: 13   train loss:  1.719982385635376
#     --->>>   episode 9 mini_epoch: 14   train loss:  1.6137514114379883
#     --->>>   episode 9 mini_epoch: 15   train loss:  1.6200904846191406
#     --->>>   episode 9 mini_epoch: 16   train loss:  1.6820930242538452
#     --->>>   episode 9 mini_epoch: 17   train loss:  1.5762112140655518
#     --->>>   episode 9 mini_epoch: 18   train loss:  1.5724323987960815
# Traning accuracy:  0.45
#     --->>>   episode 9 mini_epoch: 19   train loss:  1.4246786832809448
#     --->>>   episode 9 mini_epoch: 20   train loss:  1.3900611400604248
#     --->>>   episode 9 mini_epoch: 21   train loss:  1.3513669967651367
#     --->>>   episode 9 mini_epoch: 22   train loss:  1.2951018810272217
#     --->>>   episode 9 mini_epoch: 23   train loss:  1.2118360996246338
#     --->>>   episode 9 mini_epoch: 24   train loss:  1.1682723760604858
#     --->>>   episode 9 mini_epoch: 25   train loss:  1.1330065727233887
#     --->>>   episode 9 mini_epoch: 26   train loss:  1.092292070388794
#     --->>>   episode 9 mini_epoch: 27   train loss:  0.9985775947570801
#     --->>>   episode 9 mini_epoch: 28   train loss:  0.995503306388855
#     --->>>   episode 9 mini_epoch: 29   train loss:  0.9826103448867798
#     --->>>   episode 9 mini_epoch: 30   train loss:  1.0166829824447632
#     --->>>   episode 9 mini_epoch: 31   train loss:  0.9462421536445618
#     --->>>   episode 9 mini_epoch: 32   train loss:  0.8278301954269409
#     --->>>   episode 9 mini_epoch: 33   train loss:  0.713438093662262
#     --->>>   episode 9 mini_epoch: 34   train loss:  0.733081579208374
#     --->>>   episode 9 mini_epoch: 35   train loss:  0.6145454049110413
#     --->>>   episode 9 mini_epoch: 36   train loss:  0.6488526463508606
#     --->>>   episode 9 mini_epoch: 37   train loss:  0.6030248999595642
#     --->>>   episode 9 mini_epoch: 38   train loss:  0.6627846360206604
# Traning accuracy:  0.7375
#     --->>>   episode 9 mini_epoch: 39   train loss:  0.5446288585662842
# Generated  Tasks - num_classes: 5, n_shot: 1, n_query: 14
# Traning accuracy:  0.35714285714285715
#     --->>>   episode 10 mini_epoch: 0   train loss:  2.3515264987945557
#     --->>>   episode 10 mini_epoch: 1   train loss:  1.6018648147583008
#     --->>>   episode 10 mini_epoch: 2   train loss:  1.623604655265808
#     --->>>   episode 10 mini_epoch: 3   train loss:  1.922206163406372
#     --->>>   episode 10 mini_epoch: 4   train loss:  1.2481316328048706
#     --->>>   episode 10 mini_epoch: 5   train loss:  0.8696660995483398
#     --->>>   episode 10 mini_epoch: 6   train loss:  0.9745621681213379
#     --->>>   episode 10 mini_epoch: 7   train loss:  0.9618633985519409
#     --->>>   episode 10 mini_epoch: 8   train loss:  0.8235651850700378
#     --->>>   episode 10 mini_epoch: 9   train loss:  0.7576464414596558
#     --->>>   episode 10 mini_epoch: 10   train loss:  0.957005500793457
#     --->>>   episode 10 mini_epoch: 11   train loss:  0.6357844471931458
#     --->>>   episode 10 mini_epoch: 12   train loss:  0.6740288734436035
#     --->>>   episode 10 mini_epoch: 13   train loss:  0.6238340139389038
#     --->>>   episode 10 mini_epoch: 14   train loss:  0.6035406589508057
#     --->>>   episode 10 mini_epoch: 15   train loss:  0.7423476576805115
#     --->>>   episode 10 mini_epoch: 16   train loss:  0.4626137316226959
#     --->>>   episode 10 mini_epoch: 17   train loss:  0.4421963691711426
#     --->>>   episode 10 mini_epoch: 18   train loss:  0.42254114151000977
# Traning accuracy:  0.7
#     --->>>   episode 10 mini_epoch: 19   train loss:  0.5722706317901611
#     --->>>   episode 10 mini_epoch: 20   train loss:  0.4017186462879181
#     --->>>   episode 10 mini_epoch: 21   train loss:  0.4565578103065491
#     --->>>   episode 10 mini_epoch: 22   train loss:  0.380305677652359
#     --->>>   episode 10 mini_epoch: 23   train loss:  0.3767143189907074
#     --->>>   episode 10 mini_epoch: 24   train loss:  0.33024832606315613
#     --->>>   episode 10 mini_epoch: 25   train loss:  0.3522326350212097
#     --->>>   episode 10 mini_epoch: 26   train loss:  0.38675791025161743
#     --->>>   episode 10 mini_epoch: 27   train loss:  0.3336038291454315
#     --->>>   episode 10 mini_epoch: 28   train loss:  0.33538103103637695
#     --->>>   episode 10 mini_epoch: 29   train loss:  0.39145490527153015
#     --->>>   episode 10 mini_epoch: 30   train loss:  0.3271394670009613
#     --->>>   episode 10 mini_epoch: 31   train loss:  0.3892059028148651
#     --->>>   episode 10 mini_epoch: 32   train loss:  0.33783382177352905
#     --->>>   episode 10 mini_epoch: 33   train loss:  0.31304627656936646
#     --->>>   episode 10 mini_epoch: 34   train loss:  0.3075895607471466
#     --->>>   episode 10 mini_epoch: 35   train loss:  0.30032244324684143
#     --->>>   episode 10 mini_epoch: 36   train loss:  0.33275482058525085
#     --->>>   episode 10 mini_epoch: 37   train loss:  0.3485969007015228
#     --->>>   episode 10 mini_epoch: 38   train loss:  0.29090234637260437
# Traning accuracy:  0.7571428571428571
#     --->>>   episode 10 mini_epoch: 39   train loss:  0.3440403938293457
# Generated  Tasks - num_classes: 5, n_shot: 5, n_query: 10
# Traning accuracy:  0.24
#     --->>>   episode 11 mini_epoch: 0   train loss:  1.835506796836853
#     --->>>   episode 11 mini_epoch: 1   train loss:  1.5776230096817017
#     --->>>   episode 11 mini_epoch: 2   train loss:  1.2889492511749268
#     --->>>   episode 11 mini_epoch: 3   train loss:  1.4612513780593872
#     --->>>   episode 11 mini_epoch: 4   train loss:  1.5753531455993652
#     --->>>   episode 11 mini_epoch: 5   train loss:  1.4147480726242065
#     --->>>   episode 11 mini_epoch: 6   train loss:  1.1955245733261108
#     --->>>   episode 11 mini_epoch: 7   train loss:  1.2510480880737305
#     --->>>   episode 11 mini_epoch: 8   train loss:  1.1535989046096802
#     --->>>   episode 11 mini_epoch: 9   train loss:  1.0278757810592651
#     --->>>   episode 11 mini_epoch: 10   train loss:  1.197678565979004
#     --->>>   episode 11 mini_epoch: 11   train loss:  1.0154491662979126
#     --->>>   episode 11 mini_epoch: 12   train loss:  0.9330103993415833
#     --->>>   episode 11 mini_epoch: 13   train loss:  0.9845761060714722
#     --->>>   episode 11 mini_epoch: 14   train loss:  0.8646215200424194
#     --->>>   episode 11 mini_epoch: 15   train loss:  0.8642117381095886
#     --->>>   episode 11 mini_epoch: 16   train loss:  0.8288374543190002
#     --->>>   episode 11 mini_epoch: 17   train loss:  0.762769877910614
#     --->>>   episode 11 mini_epoch: 18   train loss:  0.5937986373901367
# Traning accuracy:  0.78
#     --->>>   episode 11 mini_epoch: 19   train loss:  0.5849062204360962
#     --->>>   episode 11 mini_epoch: 20   train loss:  0.600426971912384
#     --->>>   episode 11 mini_epoch: 21   train loss:  0.5151277780532837
#     --->>>   episode 11 mini_epoch: 22   train loss:  0.5386529564857483
#     --->>>   episode 11 mini_epoch: 23   train loss:  0.5583224296569824
#     --->>>   episode 11 mini_epoch: 24   train loss:  0.48650863766670227
#     --->>>   episode 11 mini_epoch: 25   train loss:  0.46819770336151123
#     --->>>   episode 11 mini_epoch: 26   train loss:  0.3619716763496399
#     --->>>   episode 11 mini_epoch: 27   train loss:  0.375203013420105
#     --->>>   episode 11 mini_epoch: 28   train loss:  0.3287661373615265
#     --->>>   episode 11 mini_epoch: 29   train loss:  0.34584370255470276
#     --->>>   episode 11 mini_epoch: 30   train loss:  0.32059094309806824
#     --->>>   episode 11 mini_epoch: 31   train loss:  0.34538742899894714
#     --->>>   episode 11 mini_epoch: 32   train loss:  0.280044823884964
#     --->>>   episode 11 mini_epoch: 33   train loss:  0.3233846426010132
#     --->>>   episode 11 mini_epoch: 34   train loss:  0.24257202446460724
#     --->>>   episode 11 mini_epoch: 35   train loss:  0.33607760071754456
#     --->>>   episode 11 mini_epoch: 36   train loss:  0.2617435157299042
#     --->>>   episode 11 mini_epoch: 37   train loss:  0.2250276803970337
#     --->>>   episode 11 mini_epoch: 38   train loss:  0.20908477902412415
# Traning accuracy:  0.92
#     --->>>   episode 11 mini_epoch: 39   train loss:  0.24254029989242554
# Generated  Tasks - num_classes: 5, n_shot: 3, n_query: 12
# Traning accuracy:  0.23333333333333334
#     --->>>   episode 12 mini_epoch: 0   train loss:  2.201497793197632
#     --->>>   episode 12 mini_epoch: 1   train loss:  1.6740392446517944
#     --->>>   episode 12 mini_epoch: 2   train loss:  1.4255527257919312
#     --->>>   episode 12 mini_epoch: 3   train loss:  1.6968740224838257
#     --->>>   episode 12 mini_epoch: 4   train loss:  1.6571471691131592
#     --->>>   episode 12 mini_epoch: 5   train loss:  1.5948331356048584
#     --->>>   episode 12 mini_epoch: 6   train loss:  1.2091279029846191
#     --->>>   episode 12 mini_epoch: 7   train loss:  1.3635635375976562
#     --->>>   episode 12 mini_epoch: 8   train loss:  1.0877193212509155
#     --->>>   episode 12 mini_epoch: 9   train loss:  1.128322720527649
#     --->>>   episode 12 mini_epoch: 10   train loss:  1.2347776889801025
#     --->>>   episode 12 mini_epoch: 11   train loss:  1.109537124633789
#     --->>>   episode 12 mini_epoch: 12   train loss:  0.9014142155647278
#     --->>>   episode 12 mini_epoch: 13   train loss:  0.9979837536811829
#     --->>>   episode 12 mini_epoch: 14   train loss:  0.9219980239868164
#     --->>>   episode 12 mini_epoch: 15   train loss:  0.8936015367507935
#     --->>>   episode 12 mini_epoch: 16   train loss:  0.8789315819740295
#     --->>>   episode 12 mini_epoch: 17   train loss:  0.80918949842453
#     --->>>   episode 12 mini_epoch: 18   train loss:  0.8024647831916809
# Traning accuracy:  0.7333333333333333
#     --->>>   episode 12 mini_epoch: 19   train loss:  0.6575010418891907
#     --->>>   episode 12 mini_epoch: 20   train loss:  0.6102237701416016
#     --->>>   episode 12 mini_epoch: 21   train loss:  0.5543532967567444
#     --->>>   episode 12 mini_epoch: 22   train loss:  0.5438815951347351
#     --->>>   episode 12 mini_epoch: 23   train loss:  0.46410512924194336
#     --->>>   episode 12 mini_epoch: 24   train loss:  0.49616748094558716
#     --->>>   episode 12 mini_epoch: 25   train loss:  0.4253438711166382
#     --->>>   episode 12 mini_epoch: 26   train loss:  0.35832902789115906
#     --->>>   episode 12 mini_epoch: 27   train loss:  0.38366538286209106
#     --->>>   episode 12 mini_epoch: 28   train loss:  0.36307239532470703
#     --->>>   episode 12 mini_epoch: 29   train loss:  0.30847838521003723
#     --->>>   episode 12 mini_epoch: 30   train loss:  0.27872058749198914
#     --->>>   episode 12 mini_epoch: 31   train loss:  0.4120846390724182
#     --->>>   episode 12 mini_epoch: 32   train loss:  0.3148418664932251
#     --->>>   episode 12 mini_epoch: 33   train loss:  0.1691998839378357
#     --->>>   episode 12 mini_epoch: 34   train loss:  0.1817559450864792
#     --->>>   episode 12 mini_epoch: 35   train loss:  0.13736747205257416
#     --->>>   episode 12 mini_epoch: 36   train loss:  0.12061462551355362
#     --->>>   episode 12 mini_epoch: 37   train loss:  0.14913152158260345
#     --->>>   episode 12 mini_epoch: 38   train loss:  0.11282079666852951
# Traning accuracy:  0.9666666666666667
#     --->>>   episode 12 mini_epoch: 39   train loss:  0.1066799983382225
# Generated  Tasks - num_classes: 5, n_shot: 5, n_query: 10
# Traning accuracy:  0.46
#     --->>>   episode 13 mini_epoch: 0   train loss:  2.3470120429992676
#     --->>>   episode 13 mini_epoch: 1   train loss:  1.6299488544464111
#     --->>>   episode 13 mini_epoch: 2   train loss:  1.0274876356124878
#     --->>>   episode 13 mini_epoch: 3   train loss:  1.1039390563964844
#     --->>>   episode 13 mini_epoch: 4   train loss:  1.0447816848754883
#     --->>>   episode 13 mini_epoch: 5   train loss:  0.9570553302764893
#     --->>>   episode 13 mini_epoch: 6   train loss:  0.9564864635467529
#     --->>>   episode 13 mini_epoch: 7   train loss:  0.9016137719154358
#     --->>>   episode 13 mini_epoch: 8   train loss:  0.7915262579917908
#     --->>>   episode 13 mini_epoch: 9   train loss:  0.8155152797698975
#     --->>>   episode 13 mini_epoch: 10   train loss:  0.8700585961341858
#     --->>>   episode 13 mini_epoch: 11   train loss:  0.7590250968933105
#     --->>>   episode 13 mini_epoch: 12   train loss:  0.7161063551902771
#     --->>>   episode 13 mini_epoch: 13   train loss:  0.7038685083389282
#     --->>>   episode 13 mini_epoch: 14   train loss:  0.5794950723648071
#     --->>>   episode 13 mini_epoch: 15   train loss:  0.6022708415985107
#     --->>>   episode 13 mini_epoch: 16   train loss:  0.4648113250732422
#     --->>>   episode 13 mini_epoch: 17   train loss:  0.590843915939331
#     --->>>   episode 13 mini_epoch: 18   train loss:  0.45325374603271484
# Traning accuracy:  0.86
#     --->>>   episode 13 mini_epoch: 19   train loss:  0.4041491448879242
#     --->>>   episode 13 mini_epoch: 20   train loss:  0.37815025448799133
#     --->>>   episode 13 mini_epoch: 21   train loss:  0.30815091729164124
#     --->>>   episode 13 mini_epoch: 22   train loss:  0.2596912384033203
#     --->>>   episode 13 mini_epoch: 23   train loss:  0.25467434525489807
#     --->>>   episode 13 mini_epoch: 24   train loss:  0.2425687164068222
#     --->>>   episode 13 mini_epoch: 25   train loss:  0.13799671828746796
#     --->>>   episode 13 mini_epoch: 26   train loss:  0.23667804896831512
#     --->>>   episode 13 mini_epoch: 27   train loss:  0.1668073982000351
#     --->>>   episode 13 mini_epoch: 28   train loss:  0.06472112983465195
#     --->>>   episode 13 mini_epoch: 29   train loss:  0.15049460530281067
#     --->>>   episode 13 mini_epoch: 30   train loss:  0.03886856138706207
#     --->>>   episode 13 mini_epoch: 31   train loss:  0.11157850921154022
#     --->>>   episode 13 mini_epoch: 32   train loss:  0.04192839562892914
#     --->>>   episode 13 mini_epoch: 33   train loss:  0.10911959409713745
#     --->>>   episode 13 mini_epoch: 34   train loss:  0.05840284749865532
#     --->>>   episode 13 mini_epoch: 35   train loss:  0.06452921777963638
#     --->>>   episode 13 mini_epoch: 36   train loss:  0.04761895164847374
#     --->>>   episode 13 mini_epoch: 37   train loss:  0.11818195134401321
#     --->>>   episode 13 mini_epoch: 38   train loss:  0.0426463708281517
# Traning accuracy:  1.0
#     --->>>   episode 13 mini_epoch: 39   train loss:  0.03251681849360466
# Generated  Tasks - num_classes: 8, n_shot: 2, n_query: 13
# Traning accuracy:  0.20192307692307693
#     --->>>   episode 14 mini_epoch: 0   train loss:  4.218955993652344
#     --->>>   episode 14 mini_epoch: 1   train loss:  2.7671170234680176
#     --->>>   episode 14 mini_epoch: 2   train loss:  2.12825345993042
#     --->>>   episode 14 mini_epoch: 3   train loss:  2.055755138397217
#     --->>>   episode 14 mini_epoch: 4   train loss:  2.0266830921173096
#     --->>>   episode 14 mini_epoch: 5   train loss:  2.209531307220459
#     --->>>   episode 14 mini_epoch: 6   train loss:  1.9218337535858154
#     --->>>   episode 14 mini_epoch: 7   train loss:  1.970718502998352
#     --->>>   episode 14 mini_epoch: 8   train loss:  1.8551713228225708
#     --->>>   episode 14 mini_epoch: 9   train loss:  1.8696435689926147
#     --->>>   episode 14 mini_epoch: 10   train loss:  1.848404049873352
#     --->>>   episode 14 mini_epoch: 11   train loss:  1.7851289510726929
#     --->>>   episode 14 mini_epoch: 12   train loss:  1.7884926795959473
#     --->>>   episode 14 mini_epoch: 13   train loss:  1.7422369718551636
#     --->>>   episode 14 mini_epoch: 14   train loss:  1.6964576244354248
#     --->>>   episode 14 mini_epoch: 15   train loss:  1.7076804637908936
#     --->>>   episode 14 mini_epoch: 16   train loss:  1.7077609300613403
#     --->>>   episode 14 mini_epoch: 17   train loss:  1.5695147514343262
#     --->>>   episode 14 mini_epoch: 18   train loss:  1.6217396259307861
# Traning accuracy:  0.375
#     --->>>   episode 14 mini_epoch: 19   train loss:  1.6083145141601562
#     --->>>   episode 14 mini_epoch: 20   train loss:  1.4612821340560913
#     --->>>   episode 14 mini_epoch: 21   train loss:  1.5830267667770386
#     --->>>   episode 14 mini_epoch: 22   train loss:  1.4436841011047363
#     --->>>   episode 14 mini_epoch: 23   train loss:  1.4577906131744385
#     --->>>   episode 14 mini_epoch: 24   train loss:  1.4554429054260254
#     --->>>   episode 14 mini_epoch: 25   train loss:  1.3519322872161865
#     --->>>   episode 14 mini_epoch: 26   train loss:  1.3345885276794434
#     --->>>   episode 14 mini_epoch: 27   train loss:  1.3188790082931519
#     --->>>   episode 14 mini_epoch: 28   train loss:  1.249597430229187
#     --->>>   episode 14 mini_epoch: 29   train loss:  1.1810113191604614
#     --->>>   episode 14 mini_epoch: 30   train loss:  1.0650547742843628
#     --->>>   episode 14 mini_epoch: 31   train loss:  1.1067060232162476
#     --->>>   episode 14 mini_epoch: 32   train loss:  1.0191649198532104
#     --->>>   episode 14 mini_epoch: 33   train loss:  1.0091909170150757
#     --->>>   episode 14 mini_epoch: 34   train loss:  0.9515095353126526
#     --->>>   episode 14 mini_epoch: 35   train loss:  0.8922272324562073
#     --->>>   episode 14 mini_epoch: 36   train loss:  0.8329063653945923
#     --->>>   episode 14 mini_epoch: 37   train loss:  0.8186593651771545
#     --->>>   episode 14 mini_epoch: 38   train loss:  0.8111264109611511
# Traning accuracy:  0.7211538461538461
#     --->>>   episode 14 mini_epoch: 39   train loss:  0.6826604604721069
# Generated  Tasks - num_classes: 8, n_shot: 1, n_query: 14
# Traning accuracy:  0.25892857142857145
#     --->>>   episode 15 mini_epoch: 0   train loss:  2.4598870277404785
#     --->>>   episode 15 mini_epoch: 1   train loss:  2.120603322982788
#     --->>>   episode 15 mini_epoch: 2   train loss:  1.7752879858016968
#     --->>>   episode 15 mini_epoch: 3   train loss:  1.738115668296814
#     --->>>   episode 15 mini_epoch: 4   train loss:  1.8998079299926758
#     --->>>   episode 15 mini_epoch: 5   train loss:  1.806642770767212
#     --->>>   episode 15 mini_epoch: 6   train loss:  1.6255710124969482
#     --->>>   episode 15 mini_epoch: 7   train loss:  1.6059001684188843
#     --->>>   episode 15 mini_epoch: 8   train loss:  1.5390809774398804
#     --->>>   episode 15 mini_epoch: 9   train loss:  1.5592728853225708
#     --->>>   episode 15 mini_epoch: 10   train loss:  1.377090573310852
#     --->>>   episode 15 mini_epoch: 11   train loss:  1.3423749208450317
#     --->>>   episode 15 mini_epoch: 12   train loss:  1.2856900691986084
#     --->>>   episode 15 mini_epoch: 13   train loss:  1.236228108406067
#     --->>>   episode 15 mini_epoch: 14   train loss:  1.2027512788772583
#     --->>>   episode 15 mini_epoch: 15   train loss:  1.1536153554916382
#     --->>>   episode 15 mini_epoch: 16   train loss:  1.0029877424240112
#     --->>>   episode 15 mini_epoch: 17   train loss:  0.9422090649604797
#     --->>>   episode 15 mini_epoch: 18   train loss:  1.017180323600769
# Traning accuracy:  0.625
#     --->>>   episode 15 mini_epoch: 19   train loss:  0.8884977102279663
#     --->>>   episode 15 mini_epoch: 20   train loss:  0.808914840221405
#     --->>>   episode 15 mini_epoch: 21   train loss:  0.7925229072570801
#     --->>>   episode 15 mini_epoch: 22   train loss:  0.7675771117210388
#     --->>>   episode 15 mini_epoch: 23   train loss:  0.6744118928909302
#     --->>>   episode 15 mini_epoch: 24   train loss:  0.6871365904808044
#     --->>>   episode 15 mini_epoch: 25   train loss:  0.6342803239822388
#     --->>>   episode 15 mini_epoch: 26   train loss:  0.6919434666633606
#     --->>>   episode 15 mini_epoch: 27   train loss:  0.6484387516975403
#     --->>>   episode 15 mini_epoch: 28   train loss:  0.7629780173301697
#     --->>>   episode 15 mini_epoch: 29   train loss:  0.5587415099143982
#     --->>>   episode 15 mini_epoch: 30   train loss:  0.553306519985199
